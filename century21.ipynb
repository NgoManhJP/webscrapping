# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c = r.content

soup = BeautifulSoup(c, "html.parser")

all = soup.find_all("div", {"class": "propertyRow"})

all[0].find("h4", {"class":"propPrice"}).text.replace("\n","").replace(" ","")
page_nr = soup.find_all("a",{"class":"Page"})[-1].text
print(page_nr)
# Out:
# 3

# %%
l = []
for page in range(0,int(page_nr)*10,10):
    print("http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="+str(page)+".html")
    r = requests.get(base_url+str(page)+".html")
    c = r.content
    soup = BeautifulSoup(c,"html.parser")
    all = soup.find_all("div", {"class": "propertyRow"})
for item in all:
    d = {}
    d["Price"] = item.find("h4", {"class":"propPrice"}).text.replace("\n","").replace(" ","")
    d["Address"] = item.find_all("span",{"class":"propAddressCollapse"})[0].text
    try:
        d["Locality"] = item.find_all("span",{"class":"propAddressCollapse"})[1].text
    except:
        d["Locality"] = None
    try:
        d["Beds"]=item.find("span",{"class":"infoBed"}).find("b").text
    except:
        d["Beds"]=None
    
    try:
        d["Area"] = item.find("span",{"class":"infoSqFt"}).find("b").text
    except:
        d["Area"] = None

    try:
        d["Full Baths"] = item.find("span",{"class":"infoValueFullBath"}).find("b").text
    except:
        d["Full Baths"] = None

    try:
        d["Half Baths"] = item.find("span",{"class":"infoValueHalfBath"}).find("b").text
    except:
         d["Half Baths"] = None
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        #print(column_group)
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span", {"class":"featureName"})):
            if "Lot Size" in feature_group.text:
                 d["Lot Size"] = feature_name.text
    l.append(d)
# Out:
# http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10.html
# http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html

# %%
import pandas
df = pandas.DataFrame(l)

# %%
df
# Out:
#                           Address   Area  Beds Full Baths Half Baths  \
# 0    32575 S Shadow Mountain Road  2,318     3          2       None
# 1         32750 S Shangrila Drive  2,120     3          2       None
# 2       0000 Black Canyon Highway   None  None       None       None
# 3            34775 S CHOLLA Drive  1,220     3          2       None
# 4       33403 S. HA-WA-SI TERRACE  2,000     4          2       None
# 5           34263 S Bertha Street  2,260     5          2       None
# 6             33160 S Canyon Road  1,248     3          2       None
# 7         19421 E Todd Evans Road  1,404     3          2       None
# 8              18688 E AGUA Vista   None  None       None       None
# 9   50600 N Old Black Canyon Road   None  None       None       None
# 10      20101 E SQUAW VALLEY Road   None  None       None       None
# 11            33259 S Canyon Road  1,056     3          1       None
# 12          34558 S ROADRUNNER RD    784     2          1       None
# 13       19260 E Scenic Loop Road   None  None       None       None
# 14           19000 E MAREN Avenue   None  None       None       None
# 15          19350 E SAGUARO Drive   None  None       None       None
# 16         20650 E Amethyst Place   None  None       None       None
#
#                        Locality        Lot Size     Price
# 0   Black Canyon City, AZ 85324             NaN  $299,900
# 1   Black Canyon City, AZ 85324             NaN  $167,500
# 2   Black Canyon City, AZ 85324         5 Acres  $150,000
# 3   Black Canyon City, AZ 85324             NaN  $129,500
# 4   BLACK CANYON CITY, AZ 85324             NaN  $129,000
# 5   Black Canyon City, AZ 85324             NaN   $80,000
# 6   Black Canyon City, AZ 85324             NaN   $77,900
# 7   Black Canyon City, AZ 85324             NaN   $70,500
# 8   Black Canyon City, AZ 85324       0.7 Acres   $70,000
# 9   Black Canyon City, AZ 85324         3 Acres   $67,500
# 10  Black Canyon City, AZ 85324             NaN   $54,900
# 11  Black Canyon City, AZ 85324             NaN   $45,600
# 12  Black Canyon City, AZ 85324  Under 1/2 Acre   $40,000
# 13  Black Canyon City, AZ 85324      2.35 Acres   $30,000
# 14  Black Canyon City, AZ 85324      2.05 Acres   $29,000
# 15  Black Canyon City, AZ 85324      0.73 Acres   $28,995
# 16  Black Canyon City, AZ 85324      0.31 Acres   $15,000

# %%
df.to_csv("output.csv")
